# %% [markdown]
# # Google News Embeddings for Ingredient Suggestions
# BS"D
#
# In this notebook I will get the Google News Embeddings ready to use for ingredient suggestions. I will use the gensim library to load the embeddings and then I will use the embeddings to suggest ingredients for a given ingredient.
#
# The following things need to be done to get the embeddings ready for use:
# 1. Filter out non-food items (the embeddings offer a lot of non-food words)
# 2. Setup the I/O for multi-word ingredients (e.g. "green beans"). The embeddings can handle multi-word ingredients, but they concatenate the words with underscores. We need to do the same when we want to use the embeddings, and we need to split the words when we want to display the suggestions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from gensim.models import Word2Vec
from gensim import downloader

from tqdm import tqdm

# %% [markdown]
# ## Load the Data

# %%
filepath = 'data/dataset_2.json'

raw_recipes = pd.read_json(filepath, orient='table')

raw_recipes
# Out:
#                                              ingredients
# 0      [romaine lettuce, black olives, grape tomatoes...
# 1      [plain flour, ground pepper, salt, tomatoes, g...
# 2      [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3                    [water, vegetable oil, wheat, salt]
# 4      [black pepper, shallots, cornflour, cayenne pe...
# ...                                                  ...
# 39769  [light brown sugar, granulated sugar, butter, ...
# 39770  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  [boneless chicken skinless thigh, minced garli...
# 39773  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 1 columns]

# %% [markdown]
# ## Load the Embeddings

# %%
# Download Word2Vec model
google_model = downloader.load("word2vec-google-news-300")

# %%
google_model.most_similar('chicken')
# Out:
# [('meat', 0.6799129843711853),
#  ('Chicken', 0.6726199388504028),
#  ('chickens', 0.6597973704338074),
#  ('poultry', 0.6559159755706787),
#  ('pork', 0.6541998386383057),
#  ('grilled_herbed', 0.651627242565155),
#  ('pasta_fazool', 0.6511082649230957),
#  ('boneless_chicken', 0.6347483396530151),
#  ('turkey', 0.6282519102096558),
#  ('rotisserie_roasted', 0.6275515556335449)]

# %%
google_model.most_similar("parmesan")
# Out:
# [('Parmesan_cheese', 0.7763434648513794),
#  ('pecorino', 0.7724556922912598),
#  ('Parmesan', 0.7678955793380737),
#  ('ricotta', 0.7483644485473633),
#  ('Gruyere_cheese', 0.748071014881134),
#  ('pancetta', 0.7410364747047424),
#  ('fontina', 0.7386741042137146),
#  ('parmesan_cheese', 0.7345759868621826),
#  ('mascarpone', 0.7343435883522034),
#  ('toasted_pine_nuts', 0.7295423150062561)]

# %% [markdown]
# ## Filter out Non-Food Items
# This will be done by creating a list of all the food items in the dataset and using it to filter the suggestions offered by the embeddings.
#
# This filtering should be done on the words as formatted by the embeddings, i.e. with underscores instead of spaces. Therefore, the list used for filtering should also have underscores instead of spaces.
#
# Furthermore, to prevent the filter from discarding too many suggestions, it should be case-insensitive. Every ingredient will be converted to lowercase before being checked against the list.
#
# A complication this introduces is that we will end up with fewer suggestiongs than requested. To solve this, we will request many more suggestions, filter them, and then return the top n.

# %%
all_ingredients_raw = set()

for recipe in raw_recipes['ingredients']:
    all_ingredients_raw.update(recipe)

print(all_ingredients_raw)
# Out:
# {'double smoked bacon', 'ground cashew', 'sugar', 'nori paper', 'au jus mix', 'szechwan peppercorns', 'whole wheat baguette', 'condensed cream', 'linguica', 'carrots', 'goose fat', 'french style sandwich rolls', 'ginger ale', 'low fat tortilla chip', 'mirin', 'zesty italian dressing', 'meat loaf mixture', 'hummus', 'dried fig', 'Niçoise olives', 'grill seasoning', 'low fat chunky mushroom pasta sauce', 'reduced fat cream cheese', 'cross rib roast', 'oysters', 'cooking liquid', 'chili oil', 'lingcod', 'biscuit mix', 'fine sea salt', 'lavender', 'turbinado', 'Kahlua Liqueur', 'gumbo file powder', 'baking powder', 'chinese cabbage', 'soft shelled crabs', 'vegan bouillon cubes', 'drippings', 'Spice Islands Oregano', 'mixed mushrooms', 'instant banana cream pudding', 'langoustines', 'garlic bulb', 'hard salami', 'korean vermicelli', 'nonfat dry milk', 'champagne vinegar', 'condensed fiesta nacho cheese soup', 'pure vanilla extract', 'spice cake mix', 'ti leaves', 'Neufchâtel', 'shao hsing wine', 'other vegetables', 'boneless duck breast halves', 'finely chopped fresh parsley', 'banana leaves', 'cod fillets', 'pareve margarine', 'grated orange peel', 'unsalted pistachios', 'peach pie filling', 'unsweetened vanilla almond milk', 'roquefort', 'frozen spring roll wrappers', 'sandwiches', 'compote', 'hakusai', 'dried coconut flakes', 'diced bell pepper', 'torpedo rolls', 'nuoc cham', 'raspberry jam', 'pita wedges', 'pesto sauce', 'frozen artichoke hearts', 'grapefruit', 'clotted cream', 'chocolate sticks', 'kaffir lime leaves', 'lime peel', 'mixed frozen seafood', 'organic low sodium chicken broth', 'cubed potatoes', 'ditalini pasta', 'fryers', 'capon', 'natural pistachios', 'powdered buttermilk', 'pecan meal', 'fish paste', 'togarashi', 'black moss', 'earl grey tea leaves', 'batter', 'ground lamb', 'black bean sauce with garlic', 'fresh chevre', 'crushed tomatoes', 'kirby cucumbers', 'spiny lobsters', 'pickled radish', 'cajun spice mix', 'white creme de cacao', 'lamb stew meat', 'winter melon', 'rigatoni or large tube pasta', 'Oscar Mayer Deli Fresh Smoked Ham', 'mustard powder', 'cajeta', 'pita bread', 'unsweetened dried coconut', 'grained', 'cilantro leaves', 'molasses', 'center cut bacon', 'frozen corn', 'bread and butter pickle slices', 'refrigerated pizza dough', 'chopped cilantro', 'water spinach', 'instant tapioca', 'crushed pineapple', 'orchid', 'snaps', 'table syrup', 'lean beef', 'hard shelled clams', 'bean thread vermicelli', 'custard', 'store-bought pound cake', 'refrigerated four cheese ravioli', "hellmann' or best food light mayonnais", 'vanilla cream', 'candied citron peel', 'center cut pork roast', 'organic vegetable stock', 'conch', 'stilton', 'runny honey', 'red vermouth', 'tikka paste', 'garlic pepper blend', 'dried barberries', 'low sodium cajun seasoning', 'boned skinned duck breast halves', 'wheat bran', 'shuck corn', 'orange marmalade', 'asafetida (powder)', 'hazelnut flour', 'cortland apples', 'frozen chopped broccoli', 'soy yogurt', 'boneless salmon fillets', 'tahini', 'masago', 'Classico Pasta Sauce', 'portobello caps', 'green figs', 'hot smoked paprika', 'tapioca starch', 'green leaf lettuce', 'Pillsbury™ Crescent Recipe Creations® refrigerated seamless dough sheet', 'Equal Sweetener', 'pea pods', 'thai green curry paste', 'Old El Paso™ refried beans', 'hominy', 'fruit', 'italian loaf', 'arrow root', 'vanilla vodka', 'blacan', 'Johnsonville® Mild Italian Ground Sausage', 'italian vinaigrette', 'true cinnamon', 'hothouse cucumber', 'cooked bacon', 'Ritz Crackers', 'Spanish smoked paprika', 'pie crust', 'whole wheat uncooked lasagna noodles', 'mexican style 4 cheese blend', 'sausages', 'lard', 'bucatini', 'muenster', 'spring onions', 'szechuan sauce', 'california chile', 'zest', 'stolichnaya', 'Sicilian olives', 'knorr reduc sodium chicken flavor bouillon', 'Nakano Seasoned Rice Vinegar', 'fresh mozzarella', 'dry coconut', 'grated romano cheese', 'roe', 'slaw', 'salsa verde', 'sourdough', 'cooked meatballs', 'w ...

# %%
# Format the ingredients to have underscores instead of spaces
# Also lowercase all the ingredients
all_ingredients = set()

for ingredient in all_ingredients_raw:
    all_ingredients.add(ingredient.lower().replace(' ', '_'))

# %%
print(len(all_ingredients))
print(all_ingredients)
# Out:
# 6703
# {'vegetable_demi-glace', 'pizza_crust_mix', 'beef_carpaccio', 'gluten-free_pie_crust', 'chile_powder', 'chile_puree', 'darjeeling_tea_leaves', 'bass_fillets', 'caster', 'new_york_style_panetini®_toasts', 'grated_nutmeg', 'refried_beans', 'sausages', 'baby_goat', 'flanken_short_ribs', 'crushed_pistachio', 'dairy_free_coconut_ice_cream', 'virgin_coconut_oil', 'coco', 'lamb_leg_steaks', 'store_bought_low_sodium_vegetable_stock', 'chocolate_sticks', 'baked_beans', 'unbleached_flour', 'hot_green_chile', 'pork_blood', 'ground_tumeric', 'long_buns', 'chicharron', 'preserved_lemon', 'red_wine_vinegar', 'kohlrabi', 'pace_chunky_salsa', 'malt', 'splenda_no_calorie_sweetener', 'fresh_parsley', 'fruit_juice', "soft_goat's_cheese", 'sliced_mango', 'tamari_soy_sauce', 'white_miso', 'candy_bar', 'low-fat_cream_cheese', 'gluten-free_flour', 'thai_chili_paste', 'dried_oysters', 'jambon_de_bayonne', 'frying_oil', 'jimmy_dean_pork_sausage', 'coleslaw_dressing', 'watercress', 'turnips', 'mixed_greens', 'whole_wheat_pasta', 'hominy_grits', 'texas_pete_hot_sauce', 'grappa', 'bottle_gourd', 'stem_ginger', 'chocolate_chunks', 'scallions', 'semisweet_vegan_chocolate_chips', 'instant_espresso', 'san_marzano_diced_tomatoes', 'turkey_gravy', 'skinless_salmon_fillets', 'ricotta', 'cooki_vanilla_wafer', 'clamato_juice', 'vanilla_frozen_yogurt', 'low-fat_turkey_kielbasa', 'burgers', 'ricotta_salata', 'poppy_seed_filling', 'accent_seasoning', 'beef_sirloin', 'gumbo_file', 'fine_egg_noodles', 'popcorn', 'licorice_root', 'capers', 'salted_fish', 'chocolate_truffle', 'broccoli_slaw', 'classico_pasta_sauce', 'condensed_reduced_fat_reduced_sodium_cream_of_chicken_soup', 'breadcrumb_mix', 'wish_bone_guacamol_ranch_dress', 'eau_de_vie', 'speck', 'caster_sugar', 'cocktail_pumpernickel_bread', 'sliced_olives', 'val', 'organic_milk', 'leg_quarters', 'jiffy_corn_muffin_mix', 'fingerling_potatoes', 'plantains', 'green_apples', 'beef_steak', 'cubed_pancetta', 'nori_flakes', 'dried_mission_figs', 'kraft_mexican_style_finely_shredded_four_cheese', 'brown_beech_mushrooms', 'dark_chicken_stock', 'brisket', 'anchovies', 'egg_yolks', 'cointreau_liqueur', 'whole_grain_bread', 'cooked_rice', 'shortcakes', 'kraft_reduced_fat_shredded_mozzarella_cheese', 'yellow_bean_sauce', 'raw_tiger_prawn', 'chopped_walnuts', 'cooked_italian_meatballs', 'japanese_rice_vinegar', 'arhar', 'butter_cake', 'taiwanese_bok_choy', 'salmon_roe', 'frozen_whole_kernel_corn', 'extra_wide_egg_noodles', 'calabaza', 'green_garlic', 'ginger_ale', 'soy_vay®_hoisin_garlic_marinade_&_sauce', 'shelled_shrimp', 'medium_zucchini', 'balm_leaves', 'carbonated_water', 'nonfat_block_cream_cheese', 'parsley_leaves', 'tomatillos', 'dried_split_peas', 'granola', 'soybean_sprouts', 'marshmallows', 'chiffonade', 'pork_cutlets', 'tex-mex_shredded_cheese', 'soy', 'hot_bean_paste', 'kraft_grated_parmesan_cheese', 'camellia_red_kidney_beans', 'french_bread_loaves', 'pizza_shells', 'buttermilk_cornbread', 'raw_almond', 'salmon_fillets', 'skinless_cod_fillets', 'mineral_water', 'lipton_lemon_iced_tea_mix', 'fresh_asparagus', 'whole_grain_english_muffins', 'ground_peanut', 'veal_shanks', 'chocolate-hazelnut_spread', 'sliced_kalamata_olives', 'loin_pork_chops', 'pizza_doughs', 'azteca_flour_tortillas', 'medjool_date', 'longan', 'grated_coconut', 'mushroom_soy_sauce', 'salmon_sashimi', 'fillets', 'fresh_prawn', 'french_mustard', 'whole_wheat_pita_bread', 'pheasant', 'mezcal', 'acai_juice', 'rub_seasoning', 'dried_beef', 'karo_corn_syrup', 'shahi_jeera', 'dandelion_greens', 'boneless_lamb', 'white_distilled_vinegar', 'proscuitto', 'walnuts', 'verjus', 'methi', 'promise_buttery_spread', 'maifun', 'arborio_rice', 'mixed_seafood', 'carrot_sticks', 'buttermilk', 'grape_vine_leaves', 'shredded_pepper_jack_cheese', 'hard_cheese', 'hot_chili_sauce', 'blueberri_preserv', 'table_wine', 'bread_slices', 'condensed_cheddar_cheese_soup', 'beef_broth', 'shredded_coconut', 'whole_wheat_peasant_bread', 'cooked_vegetables', 'tart_apples', 'asafetida_( ...

# %%
def get_filtered_substitutions(ingredient, top_n=10):

    # Increase the top_n to compensate for the filtering
    top_n = top_n * 10

    suggestions = google_model.most_similar(ingredient, topn=top_n)
    
    filtered_suggestions = []

    for suggestion, score in suggestions:
        if suggestion.lower().replace(' ', '_') in all_ingredients:
            filtered_suggestions.append((suggestion, score))
    
    # Remove the underscores from the suggestions
    filtered_suggestions = [(suggestion.replace('_', ' '), score) for suggestion, score in filtered_suggestions]

    # Return the top_n suggestions
    top_n = top_n // 10
    return filtered_suggestions[:top_n]

# %%
get_filtered_substitutions('parmesan', 20)
# Out:
# [('Parmesan cheese', 0.7763434648513794),
#  ('ricotta', 0.7483644485473633),
#  ('Gruyere cheese', 0.748071014881134),
#  ('pancetta', 0.7410364747047424),
#  ('fontina', 0.7386741042137146),
#  ('parmesan cheese', 0.7345759868621826),
#  ('mascarpone', 0.7343435883522034),
#  ('toasted pine nuts', 0.7295423150062561),
#  ('goat cheese', 0.7287119030952454),
#  ('pesto', 0.7269451022148132),
#  ('fontina cheese', 0.714117169380188),
#  ('prosciutto', 0.7138954401016235),
#  ('pecorino cheese', 0.7137478590011597),
#  ('gorgonzola', 0.7126846313476562),
#  ('crème fraîche', 0.7000254988670349),
#  ('gremolata', 0.699065625667572),
#  ('provolone cheese', 0.6965590119361877),
#  ('roasted garlic', 0.6964260935783386),
#  ('Parmigiano', 0.6908614039421082),
#  ('toasted almonds', 0.6900662779808044)]

# %% [markdown]
# In the above function, I filtered out non-food items *and* I set up the I/O to handle multi-word ingredients.
#
# Now the filtering list needs to be saved and the function needs to be packaged up nicely. The list will be saved here and the function will be packaged up in a separate file.

# %%
# Save the filter list to a json file
import json

file_name = "all_ingredients.json"

with open(file_name, 'w') as f:
    json.dump(list(all_ingredients), f)
