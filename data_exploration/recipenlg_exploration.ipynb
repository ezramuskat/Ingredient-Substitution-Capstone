# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Load dataset
#
# Note: pandas can load the whole dataset into one dataframe just fine on my machine; that being said, we can add an alternate chunking-based approach that would be less memory intensive (and indeed we may want to use that when we do our final ingredient collation)

# %%
df = pd.read_csv('../data_sources/recipenlg_dataset/full_dataset.csv')

# %%
df.shape
# Out:
# (2231142, 7)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'ingredients', 'directions', 'link', 'source',
#        'NER'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                  title  \
# 0           0    No-Bake Nut Cookies
# 1           1  Jewell Ball'S Chicken
# 2           2            Creamy Corn
# 3           3          Chicken Funny
# 4           4   Reeses Cups(Candy)
#
#                                          ingredients  \
# 0  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  ["1 small jar chipped beef, cut up", "4 boned ...
# 2  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4  ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
#
#                                                  NER
# 0  ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1  ["beef", "chicken breasts", "cream of mushroom...
# 2  ["frozen corn", "cream cheese", "butter", "gar...
# 3  ["chicken", "chicken gravy", "cream of mushroo...
# 4  ["peanut butter", "graham cracker crumbs", "bu...

# %%
#random sample
df.sample(10)
# Out:
#          Unnamed: 0                                     title  \
# 1470268     1470268                Cheese-And-Pepperoni Bread
# 1338861     1338861            Chicken Breasts Baked In Wine
# 1663933     1663933             Parotta recipe of south India
# 2193889     2193889           Easy Chicken Caesar Pasta Salad
# 576375       576375              Butterscotch Cheesecake Bars
# 1006151     1006151  Weight Watchers Crunchy Chinese Coleslaw
# 661724       661724                  Linguini With Clam Sauce
# 2130208     2130208                Avacado Buttermilk Sherbet
# 1849848     1849848                            Porcini Butter
# 70742         70742                           Wonderful Punch
#
#                                                ingredients  \
# 1470268  ["1 package dry yeast (about 2 1/4 teaspoons)"...
# 1338861  ["4 boneless skinless chicken breasts", "Basil...
# 1663933                           ["Maida,water,salt,oil"]
# 2193889  ["1 pkg. (11.15 oz.) KRAFT Caesar Pasta Salad"...
# 576375   ["1 (12 oz.) pkg. Butterscotch Morsels", "1/3 ...
# 1006151  ["1 lb of shredded cabbage", "1 (2 7/8 ounce) ...
# 661724   ["1/2 c. butter or margarine", "2 cloves garli...
# 2130208  ["2 each avocados", "2 cups buttermilk", "1/2 ...
# 1849848  ["1 garlic clove", "1/2 cup dried porcini mush...
# 70742    ["4 c. boiling water", "4 c. sugar", "3 pkg. J...
#
#                                                 directions  \
# 1470268  ["Dissolve yeast and sugar in warm water in a ...
# 1338861  ["Preheat oven to 350 degrees.", "Place chicke...
# 1663933  ["Take a cup of maida,add a teaspoon salt,add ...
# 2193889  ["Prepare Pasta Salad as directed on package."...
# 576375   ["Preheat oven to 350 degrees (for glass dish ...
# 1006151  ["In a large bowl, combine cabbage, noodles & ...
# 661724   ["In large frying pan melt butter or margarine...
# 2130208  ["Puree avacados in blender or food processor....
# 1849848  ["Finely chop garlic.", "In a small bowl soak ...
# 70742    ["Mix", "Jell-O", "and sugar in boiling water....
#
#                                                       link     source  \
# 1470268  www.myrecipes.com/recipe/cheese-and-pepperoni-...   Gathered
# 1338861  www.epicurious.com/recipes/member/views/chicke...   Gathered
# 1663933                    www.foodgeeks.com/recipes/21843  Recipes1M
# 2193889  www.kraftrecipes.com/recipes/easy-chicken-caes...  Recipes1M
# 576375      www.cookbooks.com/Recipe-Details.aspx?id=45130   Gathered
# 1006151  www.food.com/recipe/weight-watchers-crunchy-ch...   Gathered
# 661724       www.cookbooks.com/Recipe-Details.aspx?id=8073   Gathered
# 2130208  recipeland.com/recipe/v/avacado-buttermilk-she...  Recipes1M
# 1849848  www.epicurious.com/recipes/food/views/porcini-...  Recipes1M
# 70742      www.cookbooks.com/Recipe-Details.aspx?id=991840   Gathered
#
#                                                        NER
# 1470268  ["yeast", "sugar", "warm water", "butter", "br...
# 1338861  ["chicken breasts", "Basil", "Rosemary", "oran...
# 1663933                                          ["water"]
# 2193889   ["Chicken", "tomato King Sooper", "green onion"]
# 576375   ["Butterscotch", "butter", "Graham Cracker Cru...
# 1006151  ["cabbage", "ramen noodles", "almonds", "orang...
# 661724   ["butter", "garlic", "flour", "clams", "white ...
# 2130208  ["avocados", "buttermilk", "sugar", "honey", "...
# 1849848  ["garlic", "porcini mushrooms", "boiling-hot w...
# 70742    ["boiling water", "sugar", "Jell-O", "water", ...

# %%
#non-random sample
df[50000:51000]
# Out:
#        Unnamed: 0                                  title  \
# 50000       50000          Sandman Cookies(Or No Bake)
# 50001       50001                     Butterscotch Candy
# 50002       50002                         Macaroni Salad
# 50003       50003               3 Cheese And Carrot Tart
# 50004       50004                 Old-Fashioned Lemonade
# ...           ...                                    ...
# 50995       50995                  No Fat Gazpacho Salad
# 50996       50996                               Hot Dish
# 50997       50997             Corn And Sausage Casserole
# 50998       50998  Steamed Vegetable Platter(Serves 4)
# 50999       50999                          Mulligan Stew
#
#                                              ingredients  \
# 50000  ["1 stick butter (1/2 c.)", "2 c. sugar", "4 T...
# 50001  ["3 (12 oz.) pkg. butterscotch morsels", "1 (1...
# 50002  ["1 (8 oz.) box elbow macaroni", "1/4 c. Itali...
# 50003  ["2 Tbsp. olive oil, divided", "1 1/2 c. shred...
# 50004         ["4 lemons", "2 c. sugar", "1/2 c. water"]
# ...                                                  ...
# 50995  ["3 c. seeded, chopped tomato", "1 c. peeled, ...
# 50996  ["1 can chop suey vegetables, drained", "1 can...
# 50997  ["2 cans whole kernel corn, drained", "2 cans ...
# 50998  ["6 garlic cloves, peeled and minced", "2 tsp....
# 50999  ["2 Tbsp. shortening", "1 1/2 lb. beef stew, c...
#
#                                               directions  \
# 50000  ["Melt butter in a saucepan, then add sugar, c...
# 50001  ["Melt butterscotch morsels in microwave or do...
# 50002  ["Cook macaroni, then add Italian dressing and...
# 50003  ["Preheat oven to 425\u00b0.", "Grease 9-inch ...
# 50004  ["Cut lemon in thin slices.", "Place in a bowl...
# ...                                                  ...
# 50995  ["Combine all ingredients in a bowl, tossing g...
# 50996  ["Mix all together and cover with crushed pota...
# 50997  ["* Turkey sausage may be used instead of pork...
# 50998  ["In a 12-inch skillet, heat the oil and stir ...
# 50999  ["Melt shortening in soup kettle or Dutch oven...
#
#                                                    link    source  \
# 50000   www.cookbooks.com/Recipe-Details.aspx?id=661134  Gathered
# 50001   www.cookbooks.com/Recipe-Details.aspx?id=764863  Gathered
# 50002   www.cookbooks.com/Recipe-Details.aspx?id=794913  Gathered
# 50003   www.cookbooks.com/Recipe-Details.aspx?id=268146  Gathered
# 50004  www.cookbooks.com/Recipe-Details.aspx?id=1062403  Gathered
# ...                                                 ...       ...
# 50995   www.cookbooks.com/Recipe-Details.aspx?id=297822  Gathered
# 50996   www.cookbooks.com/Recipe-Details.aspx?id=223592  Gathered
# 50997   www.cookbooks.com/Recipe-Details.aspx?id=237399  Gathered
# 50998   www.cookbooks.com/Recipe-Details.aspx?id=830288  Gathered
# 50999   www.cookbooks.com/Recipe-Details.aspx?id=774742  Gathered
#
#                                                      NER
# 50000  ["butter", "sugar", "cocoa", "milk", "peanut b...
# 50001  ["butterscotch morsels", "extra crunchy peanut...
# 50002  ["elbow macaroni", "Italian dressing", "mayo",...
# 50003  ["olive oil", "potatoes", "salt", "fresh peppe...
# 50004                       ["lemons", "sugar", "water"]
# ...                                                  ...
# 50995  ["tomato", "cucumber", "green pepper", "green ...
# 50996  ["chop suey vegetables", "noodles", "chicken b...
# 50997  ["whole kernel corn", "corn", "sausage", "crac...
# 50998  ["garlic", "soy sauce", "freshly squeezed lemo...
# 50999  ["shortening", "beef stew", "water", "salt", "...
#
# [1000 rows x 7 columns]

# %% [markdown]
# Get some NaN info

# %%
#by column
df.isna().sum()
# Out:
# Unnamed: 0     0
# title          1
# ingredients    0
# directions     0
# link           0
# source         0
# NER            0
# dtype: int64

# %%
df[df.isna().sum(axis=1) > 0]
# Out:
#          Unnamed: 0 title         ingredients  \
# 1394448     1394448   NaN  ["2 pieces bacon"]
#
#                                                 directions  \
# 1394448  ["Slice bacon into lardons, place in nonstick ...
#
#                                   link    source        NER
# 1394448  food52.com/recipes/57431-none  Gathered  ["bacon"]
